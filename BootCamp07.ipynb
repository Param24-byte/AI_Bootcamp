# %%
import cv2
import numpy as np
import matplotlib as plt

# %%
img=cv2.imread("/content/photo(2).JPG")
print(type(img))
# Out:
# <class 'numpy.ndarray'>

# %%
print(img.shape)
# Out:
# (531, 414, 3)

# %%
from google.colab.patches import cv2_imshow
cv2_imshow(img)
# Out:
# <PIL.Image.Image image mode=RGB size=414x531>

# %%
img_resize = cv2.resize(img,(200,200))
cv2_imshow(img_resize)
# Out:
# <PIL.Image.Image image mode=RGB size=200x200>

# %%
img_flip = cv2.flip(img,1)
cv2_imshow(img_flip)
# Out:
# <PIL.Image.Image image mode=RGB size=414x531>

# %%
img_flip_1 = cv2.flip(img,0)
cv2_imshow(img_flip_1)
# Out:
# <PIL.Image.Image image mode=RGB size=414x531>

# %%
img = cv2.cvtColor(img,cv2.COLOR_BGR2GRAY)
cv2_imshow(img)
# Out:
# <PIL.Image.Image image mode=L size=414x531>

# %%
imp_crop = img[100:300,200:400]
cv2_imshow(imp_crop)
# Out:
# <PIL.Image.Image image mode=L size=200x200>
