# %%
import random

# %%
random_numbers = [random.randint(1,100) for _ in range(15)]
print("Original list: ", random_numbers)
# Out:
# Original list:  [82, 36, 61, 8, 86, 83, 65, 71, 54, 2, 48, 37, 88, 14, 41]

# %%
even_no = [num for num in random_numbers if num%2==0]
print("Even no: ", even_no)
# Out:
# Even no:  [82, 36, 8, 86, 54, 2, 48, 88, 14]
