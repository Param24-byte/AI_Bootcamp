# %%
pip install textblob
# Out:
# Requirement already satisfied: textblob in .\appdata\local\programs\python\python310\lib\site-packages (0.20.1)
# Requirement already satisfied: nltk>=3.9 in .\appdata\local\programs\python\python310\lib\site-packages (from textblob) (3.10.3)
# Requirement already satisfied: defusedxml in .\appdata\local\programs\python\python310\lib\site-packages (from nltk>=3.9->textblob) (0.7.1)
# Requirement already satisfied: click in .\appdata\local\programs\python\python310\lib\site-packages (from nltk>=3.9->textblob) (8.3.1)
# Requirement already satisfied: joblib in .\appdata\local\programs\python\python310\lib\site-packages (from nltk>=3.9->textblob) (1.3.2)
# Requirement already satisfied: regex>=2021.8.3 in .\appdata\local\programs\python\python310\lib\site-packages (from nltk>=3.9->textblob) (2026.7.19)
# Requirement already satisfied: tqdm in .\appdata\local\programs\python\python310\lib\site-packages (from nltk>=3.9->textblob) (4.67.1)
# Requirement already satisfied: colorama in .\appdata\local\programs\python\python310\lib\site-packages (from click->nltk>=3.9->textblob) (0.4.6)
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 26.0.1 -> 26.2.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
from textblob import TextBlob


def analyze_sentiment():
  print("--- Real-Time Sentiment Analyzer ---")
  print("Type any sentence to analyze. Type 'exit' to quit.\n")

  while True:
    user_input = input("Enter Text: ")

    if user_input.lower().strip() == "exit":
      print("Exiting Analyzer.")
      break

    if not user_input.strip():
      continue

    # Process text using TextBlob
    blob = TextBlob(user_input)
    polarity = blob.sentiment.polarity  # Range: -1.0 (Negative) to +1.0 (Positive)
    subjectivity = (
        blob.sentiment.subjectivity
    )  # Range: 0.0 (Factual) to 1.0 (Opinion)

    # Interpret results
    if polarity > 0.1:
      sentiment_label = "POSITIVE 🙂"
    elif polarity < -0.1:
      sentiment_label = "NEGATIVE 🙁"
    else:
      sentiment_label = "NEUTRAL 😐"

    print(f" -> Sentiment: {sentiment_label}")
    print(
        f" -> Score: Polarity={polarity:.2f}, Subjectivity={subjectivity:.2f}\n"
    )


if __name__ == "__main__":
  analyze_sentiment()
# Out:
# --- Real-Time Sentiment Analyzer ---
# Type any sentence to analyze. Type 'exit' to quit.
# Enter Text:  exit
# Exiting Analyzer.
